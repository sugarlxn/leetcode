# %%
from django.db import models

class Answer(models.IntegerChoices):
    NO = 0, "No"
    YES = 1, "Yes"
    __empty__ = "(Unknown)"

# %%
print(Answer.YES.label, Answer.YES.value)
print(Answer.NO.label, Answer.NO.value)
print(type(Answer.NO))

print(type(Answer.__empty__))
# Out:
# Yes 1
# No 0
# <enum 'Answer'>
# <class 'str'>
